# %%
from wtpsplit import SaT
# Out:
# /home/ethanlmines/blue_dir/repos/cluster-podcast-transcription/.venv/lib/python3.12/site-packages/docopt.py:165: SyntaxWarning: invalid escape sequence '\S'
#   name = re.findall('(<\S*?>)', source)[0]
# /home/ethanlmines/blue_dir/repos/cluster-podcast-transcription/.venv/lib/python3.12/site-packages/docopt.py:166: SyntaxWarning: invalid escape sequence '\['
#   value = re.findall('\[default: (.*)\]', source, flags=re.I)
# /home/ethanlmines/blue_dir/repos/cluster-podcast-transcription/.venv/lib/python3.12/site-packages/docopt.py:207: SyntaxWarning: invalid escape sequence '\['
#   matched = re.findall('\[default: (.*)\]', description, flags=re.I)
# /home/ethanlmines/blue_dir/repos/cluster-podcast-transcription/.venv/lib/python3.12/site-packages/docopt.py:456: SyntaxWarning: invalid escape sequence '\S'
#   split = re.split('\n *(<\S+?>|-\S+?)', doc)[1:]

# %%
sat = SaT("sat-12l-sm")
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 3974.02it/s]

# %%
sat.device
# Out:
# device(type='cpu')

# %%
res = list(sat.split(["I'm some sentences. what do you think", "I'lm also some sentencies Whatya think"]))
res
# Out:
# [["I'm some sentences. ", 'what do you think'],
#  ["I'lm also some sentencies ", 'Whatya think']]

# %%
res = list(res)

# %%
res
# Out:
# [["I'm some sentences. ", 'what do you think'],
#  ["I'lm also some sentencies whatya think"]]
